# %%
print('pandas')
# Out:
# pandas

# %%
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', '01numpy.ipynb', '02pandas.ipynb', 'data.csv']

# %%
df=pd.read_csv('data.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

pd.DataFrame(mydataset)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
arr1=[1,3,5,7,9]
myvar=pd.Series(arr1)

# %%
print(myvar[0])
# Out:
# 1

# %%
arr1=[1,3,5,7]
myvar=pd.Series(arr1,index=['row1','row2','row3','row4'])
myvar
# Out:
# row1    1
# row2    3
# row3    5
# row4    7
# dtype: int64

# %%
myvar['row2']
# Out:
# np.int64(3)

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)
myvar
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
type(myvar['duration'])
# Out:
# pandas.core.series.Series

# %%
type(myvar.loc[0])
print(myvar.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
myvar.loc[[0,1]]
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
pd.read_csv('data.csv')
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
pd.read_csv('https://www.w3schools.com/python/pandas/data.csv.txt')
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import urllib.request
msg='https://www.w3schools.com/python/pandas/data.csv.txt'
with (
    urllib.request.urlopen(msg) as f,
    open('data2.csv','w') as fw
    ):
    fw.write(bytes.decode(f.read(),'utf-8'))

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 9999

df = pd.read_csv('data.csv')

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df = pd.read_json('https://www.w3schools.com/python/pandas/data.js')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
msg='https://www.w3schools.com/python/pandas/data.js'
with (
    urllib.request.urlopen(msg) as f
    ):
    print(bytes.decode(f.read(),'utf-8'))
# Out:
# {
#   "Duration":{
#     "0":60,
#     "1":60,
#     "2":60,
#     "3":45,
#     "4":45,
#     "5":60,
#     "6":60,
#     "7":45,
#     "8":30,
#     "9":60,
#     "10":60,
#     "11":60,
#     "12":60,
#     "13":60,
#     "14":60,
#     "15":60,
#     "16":60,
#     "17":45,
#     "18":60,
#     "19":45,
#     "20":60,
#     "21":45,
#     "22":60,
#     "23":45,
#     "24":60,
#     "25":60,
#     "26":60,
#     "27":60,
#     "28":60,
#     "29":60,
#     "30":60,
#     "31":45,
#     "32":60,
#     "33":60,
#     "34":60,
#     "35":60,
#     "36":60,
#     "37":60,
#     "38":60,
#     "39":45,
#     "40":45,
#     "41":60,
#     "42":60,
#     "43":60,
#     "44":60,
#     "45":60,
#     "46":60,
#     "47":45,
#     "48":45,
#     "49":60,
#     "50":60,
#     "51":80,
#     "52":60,
#     "53":60,
#     "54":30,
#     "55":60,
#     "56":60,
#     "57":45,
#     "58":20,
#     "59":45,
#     "60":210,
#     "61":160,
#     "62":160,
#     "63":45,
#     "64":20,
# ...

# %%
data = {
  'Duration':{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
import json

# %%
msg=json.dumps(data) # json 형식의 문자열로

# %%
json.loads(msg) #json형식의 문자열을 dict
# Out:
# {'Duration': {'0': 60, '1': 60, '2': 60, '3': 45, '4': 45, '5': 60},
#  'Pulse': {'0': 110, '1': 117, '2': 103, '3': 109, '4': 117, '5': 102},
#  'Maxpulse': {'0': 130, '1': 145, '2': 135, '3': 175, '4': 148, '5': 127},
#  'Calories': {'0': 409, '1': 479, '2': 340, '3': 282, '4': 406, '5': 300}}

# %%
df = pd.read_csv('data.csv')
df.tail(10)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df['Calories']
# Out:
# 0       409.1
# 1       479.0
# 2       340.0
# 3       282.4
# 4       406.0
# 5       300.0
# 6       374.0
# 7       253.3
# 8       195.1
# 9       269.0
# 10      329.3
# 11      250.7
# 12      345.3
# 13      379.3
# 14      275.0
# 15      215.2
# 16      300.0
# 17        NaN
# 18      323.0
# 19      243.0
# 20      364.2
# 21      282.0
# 22      300.0
# 23      246.0
# 24      334.5
# 25      250.0
# 26      241.0
# 27        NaN
# 28      280.0
# 29      380.3
# 30      243.0
# 31      180.1
# 32      299.0
# 33      223.0
# 34      361.0
# 35      415.0
# 36      300.0
# 37      300.0
# 38      300.0
# 39      266.0
# 40      180.1
# 41      286.0
# 42      329.4
# 43      400.0
# 44      397.0
# 45      273.0
# 46      387.6
# 47      300.0
# 48      298.0
# 49      397.6
# 50      380.2
# 51      643.1
# 52      263.0
# 53      486.0
# 54      238.0
# 55      450.7
# 56      413.0
# 57      305.0
# 58      226.4
# 59      321.0
# 60     1376.0
# 61     1034.4
# ...
