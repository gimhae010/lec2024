# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.9.2'

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
X=np.array([1,2,3,4])
y=np.array([10,20,35,40])

plt.plot(X,y,'o')
plt.show()

# %%
#ypoints = np.array([3, 8, 1, 10, 5, 7])
#df=pd.Series([1,2,3,4],index=['i1','i2','i3','i4'])
df=pd.read_csv('data.csv')
X=df['Pulse']
y=df['Maxpulse']
plt.plot(X,y,'o')
#plt.plot(df,'o')
#plt.show()

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o-.r',ms=10,mfc='k')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
ypoints2 = np.array([5, 8, 3, 10])

#plt.plot(ypoints,linestyle='dashed')
plt.plot(ypoints,ls='--',color='hotpink',linewidth='5')
plt.plot(ypoints2,'o-')
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage", fontdict=font2)
plt.title("Sports Watch Data",fontdict=font1, loc = 'left')
plt.grid(axis='y')
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 4)
plt.plot(x,y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

#plt.plot(x, y,'o')
plt.scatter(x, y)
plt.show()

# %%
df=pd.read_csv('data.csv')
X=df['Pulse']
y=df['Maxpulse']
plt.scatter(X,y, alpha=0.2,c='#000000')

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [161.8075219  149.43999419 170.51522654 176.1632693  166.94809771
#  153.25235758 169.07630161 174.72506436 172.71907217 175.73723139
#  167.92154039 161.6702147  175.49279877 182.88957779 175.41378908
#  157.74586059 170.73797562 172.06634457 164.47532932 154.5646333
#  158.50001053 178.276991   169.06223849 156.47060522 165.99129523
#  175.2989787  165.49497658 171.2969054  172.76528331 184.8043534
#  154.68324653 164.54354036 155.2713803  163.22743505 178.18266978
#  172.35782041 171.0773015  176.06239944 157.90458225 183.91490439
#  164.38725655 173.21808248 168.39501219 157.01070978 171.71411825
#  157.1924012  169.5103144  171.28924269 161.06234349 162.84567222
#  168.4868911  165.24864937 143.79696856 167.53949264 170.56402645
