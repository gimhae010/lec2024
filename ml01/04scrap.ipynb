# %%
from urllib.request import Request

# %%
import urllib.request
msg='https://m.naver.com/'
with (
    urllib.request.urlopen(msg) as f,
    open('data2.csv','w') as fw
    ):
    print(bytes.decode(f.read(),'utf-8'))
# Out:
# <!doctype html>                                                        <html lang="ko" class="web fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta name="referrer" contents="always"> <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 모바일 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버 모바일 메인"> <meta property="og:url" content="http://m.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/20240816_0/upload_17238016633431Iokd.jpg"> <meta property="og:description" content="네이버 모바일 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content="네이버 모바일 메인"> <meta name="twitter:url" content="http://m.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/20240816_0/upload_17238016633431Iokd.jpg"> <meta name="twitter:description" content="네이버 모바일 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <title>NAVER</title>  <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602713093y05hN.png"/> <link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602618538tqxrL.png"/> <link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602698312FhzB6.png"/> <link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602600973mkojJ.png"/>  <link rel="stylesheet" type="text/css" href="https://mm.pstatic.net/css/ncache/build/w.b6648cf4.css"> <link rel="stylesheet" type="text/css" href="https://mm.pstatic.net/css/ncache/build/w_dark.4ef58721.css" media="false">  <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico"> <link rel="canonical" href="https://www.naver.com/"> <script>window.nsc="mtop.v6",window.svt="20241203172311",window.g_ssc=window.nsc,window.nmain={},window.logsrv="l.m.naver.com"</script> <script> window.nmain.buildTime = "202412031054";
#     window.nmain.gv = {
#       jsOrigin: "m",  isLogin: false,   generation : -1,   isContentsOnly: false,
#       isApp: false,
#       isPad: false,
#       isWhaleSidebar: false,
#       daInfo: {"SHOPPING_MEN_W":{"adType":"sequence","units":[{"unitId":"m_main_shoppingwest_1st","divId":"nmap_shopping_men_w_1","position":"abs","positionIndex":4,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_shopping_west_0size","divId":"nmap_shopping_men_w_3","position":"abs","positionIndex":9,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":"men"}},{"unitId":"m_main_shoppingwest_2nd","divId":"nmap_shopping_men_w_2","position":"abs","positionIndex":11,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}}]},"DISCOVER":{"adType":"sequence","units":[{"unitId":"m_main_watch_top","divId":"nmap_discover_top","position":"rel","positionIndex":0,"adPositionAdjustFlag":true,"adCallType":"preload","extraOption":{"calp":null}},{"unitId":"m_main_pick_feed","divId":"nmap_discover_6","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}}]},"SHOP-TODO-KIDS":{"adType":"sequence","units":[{"unitId":"m_main_todokids_1st","divId":"nmap_shop-todo-kids_1","position":"abs","positionIndex":4,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_todokids_2nd","divId":"nmap_shop-todo-kids_2","position":"abs","positionIndex":9,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}}]},"ENT":{"adType":"sequence","units":[{"unitId":"m_main_ent_1st","divId":"nmap_ent_1","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_ent_2nd","divId":"nmap_ent_2","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_ent_3rd","divId":"nmap_ent_3","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_ent_top","divId":"nmap_ent_top","position":"rel","positionIndex":0,"adPositionAdjustFlag":true,"adCallType":"preload","extraOption":{"calp":null}}]},"WEBTOON":{"adType":"sequence","units":[{"unitId":"m_main_webtoon_1st","divId":"nmap_bboom_1","position":"abs","positionIndex":1,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_webtoon_2nd","divId":"nmap_bboom_2","position":"abs","positionIndex":5,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_webtoon_top","divId":"nmap_bboom_top","position":"rel","positionIndex":0,"adPositionAdjustFlag":true,"adCallType":"preload","extraOption":{"calp":null}}]},"NEWS_FEED":{"adType":"sequence","units":[{"unitId":"m_main_newsfeed_1st","divId":"nmap_news_feed_1","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_newsfeed_2nd","divId":"nmap_news_feed_2","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_newsfeed_3rd","divId":"nmap_news_feed_3","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_newsfeed_top","divId":"nmap_news_feed_top","position":"rel","positionIndex":0,"adPositionAdjustFlag":false,"adCallType":"preload","extraOption":{"calp":null}}]},"DISCOVER-RECOMMEND":{"adType":"sequence","units":[{"unitId":"m_main_watch_top","divId":"nmap_discover_recommend_top","position":"rel","positionIndex":0,"adPositionAdjustFlag":true,"adCallType":"preload","extraOption":{"calp":null}},{"unitId":"m_main_pick_feed","divId":"nmap_discover_recommend_1","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}}]},"SPORTS":{"adType":"sequence","units":[{"unitId":"m_main_sports_1st","divId":"nmap_sports_1","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_sports_2nd","divId":"nmap_sports_2","position":" ...
#       osType: "",
#       uaFrom: "(none)",
#       pcThemeMode: "light",
#       useNSCS: false,
#       mainVersion: 2,
#       lat: "(none)",
#       lng: "(none)",
#     };
#     window.naver = {
#       main: {
#         gVariable: {
#           bContentOnly: window.nmain.gv.isContentsOnly, // 광고에서 사용
#         },
#         LcsLog: {
#           lcsDo: function(panel, htParams) { setTimeout(function() { naver.main.LcsLog.lcsDo(panel, htParams); }, 500); }
#         },
#         NaverApp: {
#           lcsDo: function(panel, htParams) { setTimeout(function() { naver.main.NaverApp.lcsDo(panel, htParams); }, 500); }
#         }
#       }
#     };
#     window.nmain.raw = {};
#     window.nmain.raw.menu = [{"code":"ANIMAL","parentPanelCode":"","groupCode":"CONTENTS","title":"동물공감","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/2021/0512/upload_1620798904970JncrR.png","badge":"CLOSE","badgeText":"종료 예정","naviTooltipTitle":null,"nclickAreaCode":"ani","lcsCode":"m_main_animal","enabled":false,"subMenuList":[],"jvMeta":{"editor":"(주)동그람이","url":"http://m.blog.naver.com/animalandhuman/221081025234","updateTime":"2017.08.24"},"topLevelPanel":true},{"code":"ARRIVAL-GUARANTEE","parentPanelCode":"","groupCode":"COMMERCE","title":"도착보장","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/20230508_0/upload_1683512306095hsWXM.png","badge":"NEW","badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"avgt","lcsCode":"m_main_avgt","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":true},{"code":"BBOOM","parentPanelCode":"","groupCode":"CONTENTS","title":"웹툰","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/20230508_0/upload_1683512503558oR7Iq.png","badge":null,"badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"wtn","lcsCode":"m_main_wtn","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":true},{"code":"BEAUTY","parentPanelCode":"","groupCode":"COMMERCE","title":"패션뷰티","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/20230508_0/upload_1683512587155Hph1W.png","badge":null,"badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"bty","lcsCode":"m_main_beauty","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":true},{"code":"BEAUTY-MISTER","parentPanelCode":"BEAUTY","groupCode":"COMMERCE","title":"패션뷰티미스터","type":"WEB","iconUrl":null,"badge":null,"badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"mr","lcsCode":"m_main_beautymr","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":false},{"code":"BEAUTY-WOMEN","parentPanelCode":"BEAUTY","groupCode":"COMMERCE","title":"패션뷰티우먼","type":"WEB","iconUrl":null,"badge":null,"badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"bty","lcsCode":"m_main_beauty","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":false},{"code":"BOOM","parentPanelCode":"","groupCode":"CONTENTS","title":"뿜","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/20230508_0/upload_1683512365973c4uBi.png","badge":null,"badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"bom","lcsCode":"m_main_boom","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":true},{"code":"BRAND","parentPanelCode":"SHOPPING","groupCode":"CONTENTS","title":"브랜드","type":"WEB","iconUrl":null,"badge":null,"badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"brdpan","lcsCode":"m_main_shopping_b","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":false},{"code":"BUSINESS","parentPanelCode":"","groupCode":"CONTENTS","title":"비즈니스","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/2021/0512/upload_16207990345023pNG7.png","badge":"CLOSE","badgeText":"종료 예정","naviTooltipTitle":null,"nclickAreaCode":"bus","lcsCode":"m_main_business","enabled":false,"subMenuList":[],"jvMeta":{"editor":"(주)인터비즈","url":"http://m.blog.naver.com/naver_business/220964064035","updateTime":"2017.05.26"},"topLevelPanel":true},{"code":"CARGAME","parentPanelCode":"","groupCode":"CONTENTS","title":"자동차","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/20230508_0/upload_1683512518207eox3y.png","badge":null,"badgeText":null,"naviTooltipTitle":null,"nclickAreaCode":"cat","lcsCode":"m_main_cargame","enabled":true,"subMenuList":[],"jvMeta":null,"topLevelPanel":true},{"code":"CHINA","parentPanelCode":"","groupCode":"CONTENTS","title":"중국","type":"WEB","iconUrl":"https://s.pstatic.net/static/www/mobile/edit/2021/0512/upload_1620799068464n1eqG.png","badge":"CLOSE","badgeText":"종료 예정","naviTooltipTitle":null,"nclickAreaCode":"cha","lcsCode":"m_main_china","enabled":false,"subMenuList":[],"jvMeta":{"editor":"(주)차이나랩","url":"https://m.blog ...
#     window.nmain.raw.menuDefaultTarget = {"MALE_25_255":{"COMMERCE":["SHOP_VOGUE","BEAUTY","ARRIVAL-GUARANTEE","GIFT-SHOP","CULTURE","PLUS-DEAL","FOOD-MARKET","SHOP-LIVE"],"HOME":["SEARCH"],"MYTAB":["MYTAB"],"CLIP":["SHORTS-RECOMMEND"],"CONTENTS":["NEWS","SPORTS","ENT","DATA","SHOPPING","CARGAME","GAMEAPP","SHORTS","HEALTH","BBOOM","LECTURE","PLACE","SHOP-TODO","LIVING","LIVINGHOME"]},"FEMALE_0_255":{"COMMERCE":["SHOP_VOGUE","BEAUTY","ARRIVAL-GUARANTEE","GIFT-SHOP","SHOP-LIVE","FOOD-MARKET","PLUS-DEAL","CULTURE"],"HOME":["SEARCH"],"MYTAB":["MYTAB"],"CLIP":["SHORTS-RECOMMEND"],"CONTENTS":["NEWS","ENT","SHOPPING","SPORTS","DATA","HEALTH","SHORTS","LECTURE","BBOOM","PLACE","SHOP-TODO","LIVING","LIVINGHOME","CARGAME","GAMEAPP"]},"MALE_0_24":{"COMMERCE":["SHOP_VOGUE","BEAUTY","ARRIVAL-GUARANTEE","GIFT-SHOP","CULTURE","PLUS-DEAL","FOOD-MARKET","SHOP-LIVE"],"HOME":["SEARCH"],"MYTAB":["MYTAB"],"CLIP":["SHORTS-RECOMMEND"],"CONTENTS":["NEWS","SPORTS","ENT","DATA","SHOPPING","CARGAME","GAMEAPP","SHORTS","HEALTH","BBOOM","LECTURE","PLACE","SHOP-TODO","LIVING","LIVINGHOME"]},"DEFAULT":{"COMMERCE":["SHOP_VOGUE","BEAUTY","ARRIVAL-GUARANTEE","GIFT-SHOP","SHOP-LIVE","FOOD-MARKET","PLUS-DEAL","CULTURE"],"HOME":["SEARCH"],"MYTAB":["MYTAB"],"CLIP":["SHORTS-RECOMMEND"],"CONTENTS":["NEWS","ENT","SPORTS","SHOPPING","DATA","SHORTS","HEALTH","GAMEAPP","LECTURE","BBOOM","PLACE","SHOP-TODO","CARGAME","LIVING","LIVINGHOME"]}};
#     window.nmain.env = 'prd';
#
#     window.nmain.homefeed = "true";
#
#     (function() {
#       var i = 0;
#       for (i = 0; i < window.nmain.raw.menu.length; i++) {
#         var menu = window.nmain.raw.menu[i];
#
#         // [쇼핑탭] W쇼핑판 예외처리
#         if (menu.code === 'SHOP_VOGUE') {
#           menu.type = 'WEB';
#         }
#
#         // [클립판] 예외처리
#         // 클립인기판 / 클립추천판
#         if (menu.code === 'SHORTS') {
#           menu.type = 'SubTab';
#           menu.subMenuList = ['SHORTS-RECOMMEND', 'SHORTS-HOT'];
#         }
#         if (menu.code === 'SHORTS-RECOMMEND') {
#           menu.type = 'WEB';
#           menu.enabled = true;
#           menu.parentPanelCode = 'SHORTS';
#         }
#         if (menu.code === 'SHORTS-HOT') {
#           menu.type = 'WEB';
#           menu.enabled = true;
#           menu.parentPanelCode = 'SHORTS';
#         }
#       }
#     })(); </script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <!-- Naver Tag Manager --> <script type="text/javascript">!function(t,n){n=n||"ntm",window["ntm_"+t]=n,window[n]=window[n]||[],window[n].push({"ntm.start":+new Date}),t=document.getElementsByTagName("script")[0],(n=document.createElement("script")).async=!0,n.src="https://ntm.pstatic.net/scripts/ntm_17c5bf488690.js",t.parentNode.insertBefore(n,t)}("17c5bf488690","ntm")</script> <!-- End Naver Tag Manager -->   <style>.flick-container{overflow:hidden;position:relative}.flick-wrap{overflow:hidden;position:relative}.flick-panel{float:left;width:100%;position:relative;-webkit-overflow-scrolling:touch}#MM_PADDING_TOP{padding-top: 0px}img[data-src]{min-height:2px;visibility:hidden}</style> <script src="https://mm.pstatic.net/js/build/index_head.484e8d02.js?o=m" crossorigin="anonymous" onerror='window.nmain.sendNelo("[Load Failed] "+this.src)'></script></head> <body class="on_animation">      <header class="header header_fixed header_fixed_in header_new" id="HEADER" style="transform:translateY(-100%)"> <div id="sch" class="sch"> <section> <div id="sch_w" class="sch_wrap region_greendot _sch_w"> <div class="sch_inner"> <div class="sch_logo"> <a href="/" class="sch_logo_naver MM_SEARCH_GO_HOME" data-sclk="naverlogo"> <span class="sch_ico_mask"></span> <span class="blind">NAVER</span> </a> </div> <a id="MM_SEARCH_BACK" href="#" class="sch_btn_back" data-sclk="searchback"><span class="blind">이전 페이지</span></a> <form name="search" role="search" action="https://m.search.naver.com/search.naver"> <div class="sch_input_wrap"> <input type="hidden" name="sm" value="mtp_hty.top"> <input type="hidden" name="where" value="m"> <input id="query" type="search" name="query" title="검색어를 입력해주세요." placeholder="검색어를 입력해주세요." class="sch_input" autocomplete="off" maxlength="255" autocapitalize="off" onfocus='this.setAttribute("data-focus","focus")'> <button id="clear_input" type="button" class="sch_btn_reset"><span class="blind">입력 내용 삭제</span></button> </div> <button type="submit" class="sch_btn_search MM_SEARCH_SUBMIT"> <span class="sch_ico_mask"></span> <span class="blind">검색</span> </button>  <div class="sch_region"> <button id="MM_HEADER_GREENDOT" type="button" class="sch_btn_region sch_greendot"> <span class="blind">그린닷</span> </button> </div>  </form> </div> </div> <!--[FE] 'ac-layer-root' id 정의--> <div id="ac-layer-root" class="u_atcp_wrap"></div> </section> </div> <div class="nav_wrap">   <nav class="nav " id="NAV"> <span class="nav_mask_prev"></span> <span class="nav_mask_next"></span> <div class="nav_scroll_wrap"> <div class="nav_list_wrap native_scroll" id="NAV_LIST"> <ul role="tablist" class="nav_list native_scroll_list">   <li role="presentation" class="nav_item" data-code="SEARCH"><a href="#SEARCH" role="tab" class="nav_link nav_search" aria-selected="true"><span class="blind">홈</span></a></li> <li role="presentation" class="nav_item" data-code="NEWS"><a href="#NEWS" role="tab" class="nav_link nav_news" aria-selected="false"><span class="blind">뉴스</span></a></li><li role="presentation" class="nav_item" data-code="ENT"><a href="#ENT" role="tab" class="nav_link nav_ent" aria-selected="false"><span class="blind">엔터</span></a></li><li role="presentation" class="nav_item" data-code="SPORTS"><a href="#SPORTS" role="tab" class="nav_link nav_sports" aria-selected="false"><span class="blind">스포츠</span></a></li><li role="presentation" class="nav_item" data-code="SHOPPING"><a href="#SHOPPING" role="tab" class="nav_link nav_shopping" aria-selected="false"><span class="blind">쇼핑투데이</span></a></li><li role="presentation" class="nav_item" data-code="DATA"><a href="#DATA" role="tab" class="nav_link nav_data" aria-selected="false"><span class="blind">경제</span></a></li><li role="presentation" class="nav_item" data-code="SHORTS"><a href="#SHORTS" role="tab" class="nav_link nav_shorts" aria-selected="false"><span class="blind">클립</span></a></li><li role="pre ...
# <div id="MM_logo" class="sch_logo_container sch_logo_container_new " data-block-id=""
# data-block-code="CAS_6170c5c1d52dbb4f2157aefa"
# data-block-type="LOGO-BLOCK"
# data-block-position="1"
# data-template-code="SEARCH-LOGO"
#
# >
# <div class="sch">
# <section>
# <div class="sch_wrap region_greendot" >
# <div class="sch_inner">
# <h1 class="sch_logo">
# <a href="/" class="sch_logo_naver"
# data-clk="nlogo">
# <span class="sch_ico_mask MM_search_color" style="background: #ffffff;"
# data-color=""
# ></span>
# <span class="blind">NAVER</span>
# </a>
# </h1>
# <form name="search" role="search" action="https://m.search.naver.com/search.naver">
# <div class="sch_input_wrap">
# <input id="MM_SEARCH_FAKE" name="query" type="search" title="검색어를 입력해주세요."
# placeholder="검색어를 입력해주세요."
# autocomplete="off" class="sch_input MM_SWIPE_IGNORE">
# <input type="hidden" name="sm" value="mtp_hty.top">
# <input type="hidden" name="where" value="m">
# </div>
# <button type="submit" class="sch_btn_search" ><span class="blind">검색</span></button>
#
# <div class="sch_region">
# <button id="MM_GREENDOT" type="button" class="sch_btn_region sch_greendot">
# <span class="blind">그린닷</span>
# </button>
# </div>
#
# </form></div>
# </div>
# </section>
# </div><div class="sch_home_shortcut" id="HOME_SHORTCUT" style="visibility:hidden">
# <h2 class="blind">바로가기</h2>
# <ul class="shs_list">
# <li class="shs_item">
# <a class="shs_link ITEM" href="/naverapp/?version=3&cmd=onMenu&menuCode=NEWS&showToast=true"
# data-code="menu.NEWS" data-clk="shortnew">
# <div class="shs_service_mw">
# <img width="44" height="44" alt="" class="shs_service_m"
# data-src="https://s.pstatic.net/static/www/mobile/edit/20240926_0/upload_1727340529461tGtV8.png"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </div>
# <span class="shs_text">뉴스판</span>
# </a>
# </li>
# <li class="shs_item">
# <a class="shs_link ITEM" href="https://shopping.naver.com/ns/home" data-clk="shortsho">
# <div class="shs_service_mw">
# <img width="44" height="44" alt="" class="shs_service_m"
# data-src="https://s.pstatic.net/static/www/mobile/edit/20240926_0/upload_1727340609927a4VUk.png"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </div>
# <span class="shs_text">스토어</span>
# </a>
# </li>
# <li class="shs_item">
# <a class="shs_link ITEM" href="/naverapp/?version=3&cmd=onMenu&menuCode=DATA&showToast=true"
# data-code="menu.DATA" data-clk="shortecn">
# <div class="shs_service_mw">
# <img width="44" height="44" alt="" class="shs_service_m"
# data-src="https://s.pstatic.net/static/www/mobile/edit/20240926_0/upload_1727340640840FWUt0.png"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </div>
# <span class="shs_text">경제판</span>
# </a>
# </li>
# <li class="shs_item">
# <a class="shs_link ITEM" href="/naverapp/?version=3&cmd=onMenu&menuCode=SHORTS&showToast=true"
# data-code="menu.SHORTS" data-clk="shortsfp">
# <div class="shs_service_mw">
# <img width="44" height="44" alt="" class="shs_service_m"
# data-src="https://s.pstatic.net/static/www/mobile/edit/20240926_0/upload_1727340671003TqsLB.png"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </div>
# <span class="shs_text">클립판</span>
# </a>
# </li>
# <li class="shs_item">
# <a class="shs_link ITEM" href="https://m.mail.naver.com" data-code="svc.mail:1" data-clk="shortmail">
# <div class="shs_service_mw">
# <img width="44" height="44" alt="" class="shs_service_m"
# data-src="https://s.pstatic.net/static/www/mobile/edit/20240926_0/upload_1727340694234hLngf.png"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </div>
# <span class="shs_text">메일</span>
# </a>
# </li>
# <li class="shs_item">
# <a class="shs_link ITEM" href="https://m.cafe.naver.com" data-code="svc.cafe:1" data-clk="shortcafe">
# <div class="shs_service_mw">
# <img width="44" height="44" alt="" class="shs_service_m"
# data-src="https://s.pstatic.net/static/www/mobile/edit/20240926_0/upload_1727340716454Pctgy.png"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </div>
# <span class="shs_text">카페</span>
# </a>
# </li>
# <li class="shs_item">
# <a class="shs_link ITEM" href="https://m.blog.naver.com" data-code="svc.blog:1" data-clk="shortblog">
# <div class="shs_service_mw">
# <img width="44" height="44" alt="" class="shs_service_m"
# data-src="https://s.pstatic.net/static/www/mobile/edit/20240926_0/upload_1727340486286Jh4lB.png"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </div>
# <span class="shs_text">블로그</span>
# </a>
# </li>
# <li class="shs_item">
# <a href="/services.html" class="shs_link" data-clk="shortallser">
# <div class="shs_service_mw">
# <picture>
# <source srcset="https://s.pstatic.net/static/www/mobile/edit/2021/0427/upload_1619497871869hiEPw.png" media="false"
# >
# <img data-src="https://s.pstatic.net/static/www/mobile/edit/2021/0427/upload_1619497854375Q53rw.png"
# width="44" height="44" alt="" class="shs_service_m"
# onerror="this.parentNode.outerHTML='<span class=\'comp_noimage\'><span class=\'blind\'>이미지 준비중</span></span>';">
# </picture>
# </div>
# </a>
# </li>
# </ul>
# </div><div class="sch_aside_wrap">
# <div class="sch_home_aside ">
# <div class="sha_service">
# <a href="/aside/" class="sha_aside_link" data-clk="drawer">
# <span class="sha_ico_aside"><span class="blind">확장 영역</span></span>
# </a>
# </div>
#
# <div class="sha_service">
# <a href="https://new-m.pay.naver.com/mydata/home?from=main_pay_icon" class="sha_npay_link" data-clk="qrnpay">
# <span class="sha_ico_npay"><span class="blind">네이버페이</span></span>
# <span class="sch_ico_new MM_pay_count" style="display: none;"><span class="blind">new</span></span>
# </a>
# </div>
# <div id="MM_MY_CART" class="sha_service">
# <a href="https://m.shopping.naver.com/cart" class="sha_cart_link" data-clk="cart">
# <span class="sha_ico_cart"><span class="blind">장바구니</span></span>
# <span class="sch_ico_new MM_cart_count" style="display: none;"><span class="blind">new</span></span>
# </a>
# </div>
#
# </div><div class="sch_home_mydata ">
#
# <div id="MM_MYSPACE_TALK" class="shm_service">
# <a href="https://talks.naver.com/" class="shm_talk_link" data-clk="talk">
# <span class="shm_ico_talk"><span class="blind">톡</span></span>
# <span class="shm_alarm_count MM_MYSPACE_TALK_COUNT" style="display: none;"></span>
# </a>
# <a href="" class="shm_notify_nudge MM_MYSPACE_TALK_NUDGE">
# <div class="shm_nudge_tooltip">
# <p class="shm_message"></p>
# </div>
# </a>
# </div>
# <div id="MM_MYSPACE_NOTI" class="shm_service">
# <a href="https://m.notify.naver.com/" class="shm_notify_link MM_MYSPACE_NOTI_ICON" data-clk="drwicon">
# <span class="shm_ico_notify">
# <span class="blind">알림</span>
# </span>
#
# </a>
# <a href="#" class="shm_notify_nudge MM_MYSPACE_NOTI_COACH">
# <div class="shm_nudge_tooltip">
# <p class="shm_message"></p>
# </div>
# </a>
# </div>
#
# <div class="shm_service">
# <a href="https://my.naver.com/" class="shm_na_link" data-clk="profileclick">
# <span class="blind">네이버 Na</span>
# <div class="shm_na_profile">
# <span class="shm_ico_na"><span class="blind">통합MY</span></span>
# <span id="MM_mytab_dot" class="sch_ico_new" style="display: none;"><span class="blind">new</span></span>
# </div>
# </a>
# </div>
# </div></div>
# </div>
#
#
#
# <div id="HOME_AD" class="id_nmap" style="overflow:visible; max-height:140px;height:calc(14000vw/375);" data-block-id=""
# data-block-code="CAS_6170c5e40241b248b5fc5bc4"
# data-block-type="BLOCK-SEARCH-SPECIAL-DA"
# data-block-position="2"
# data-template-code="SEARCH-SPECIAL-DA"
#
# >
# <div class="nmap_wrapper" style="height:100%">
# <div id="main_search_specialda_1" data-main-da="_MM_MAIN_DA" data-veta-preview="main_search_specialda_1" style="height:100%"></div>
# </div>
# <script id="special-da-server-script" >
# (function() {
# var ads = {"payload":{"requestId":"d2cf178c588d46629dff7e9f5fd9dbcf","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"m_main_special","randomNumber":11,"adDivId":"main_search_specialda_1","advertiserDomains":["www.tiffany.kr"],"adDuplicationKeys":["URL:https://www.tiffany.kr"],"ads":[{"encrypted":"OgzaC6fVYwB-Ruh2Aiq9i6zEegHPvV7pzncu90O9UWlyQR0QeO4kPhbLTGys_1kzBOk7H-NqE_JJ1UaCe0KVUQ8CQ2zwLGvWGTYlU0vnL-eUcjK1RaBGqOFCEeXvhjeOrw4yqKFZwZouYb5N2IvRIbs7fH1Dma93wishiRYc-rEk_J3wAjMcYcQ9iWuXHqXCo9NTFgwy9k9H4kiS1aFYO9aKVJuxZnU7NZuaR2EhGCtcrHt_ghjKkixeWpUeBtipGTaVWcrTOzdtg8E1zX0JFD9Si796tBLSaOXJ50Uh0uIsAhS8_mHVAIs-oOZzDjf1dnKIZz7vKeNH1h6VmP_5mt-9KUhV5_QeFjGHFgBlLmbi6Gw24ldX-tPNOpwRGUj8XpG8JKYYOYm9j0p7muCWymhbAf5O5CXDksxZwkXHUF5esC84xTICR6RwIE09acjXqRxnIA6kRr3ED_-dh9cM87x26p3-aiX2y-Wg0ntsWYP6MusV7x51kP63FnuPxrbnXa-Jiv8hfBR_zWEX5R9RtvtscVditC0SE8igcRNQ1xPzF07Jt7mAta2QriKE9rO72hO6uqQUmsyIYpbpupuOTnJBJe8vyq4nGju3bONK3LLRchFr5BOqNz_oi8Z0YTB2s2YBD6V_ZU9OzHJEqGqFSiGUCp_WhGNGRgKlAWCV9XgpZMPenlxiJdbVe9HoqbGXt3a7mEA_0hvjrMqn2-znCiMd99WqwUx4GyK1RLYSGrY35K2HglpIcOPSYys7riP-b7UHY-33FAwnYPdZpVoENw==","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"NDP","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10042822\u0026calp=-\u0026oj=dZ2qDmtmLJhL30K18jogwJHdP4PIX9nigSJjAYFCwdSMHNwsKTUvzQaKXY7%2Bydr0JL1qM2Pf%2FalkLAdoxJtfzQDXXII%2BH8C7Yo%2FxOcI1GswvKEh7Q73%2BZ2obtMN4PrY5DDF%2FNs3OBtZF4lcASwO4jszLU35oUQjhQa%2BDLzv7yk4QXB61g96gVjfObGKgiqRCXFuT2Nq6%2F5G7VfiFWhhdzzsCzADIeOUD\u0026ac=9056597\u0026src=7377863\u0026evtcd=BID_WIN\u0026x_ti=1446\u0026rk=5vz1qG6_0Sq3oDOVMwoaUw\u0026eltts=mGHLyxR48YMP%2FVsjjrs2nA%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"63f85a6adc8a06002e9247bd","adomain":["www.tiffany.kr"],"cid":"1515730","crid":"2697464","exp":2207,"adm":"%3C%21--%20%5Bsearch_home_prod_type%3Apremium%5D%20--%3E%0D%0A%3C%21--%20%5B%EB%AA%A8%EB%B0%94%EC%9D%BC%5D%20%EB%A9%94%EC%9D%B8_%EC%8A%A4%ED%8E%98%EC%85%9CDA_%EB%8F%99%EC%98%81%EC%83%81%ED%99%95%EC%9E%A5%ED%98%95%28200%29%20--%3E%0D%0A%3C%21--%202024.1.25.%20--%3E%0D%0A%0D%0A%0D%0A%20%20%20%20%3C%21--%20%EB%8F%99%EC%98%81%EC%83%81%20%ED%99%95%EC%9E%A5%ED%98%95%20--%3E%0D%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20type%3D%22text%2Fcss%22%20href%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fcss%2Fmo%2Fmain%2Fmin%2Fmocoplex_video_extension_edit_16_9_nnmain.min.css%3F20201230%22%3E%0D%0A%20%20%20%20%3Cdiv%20data-container-id%3D%22main_specialda_main_container%22%20class%3D%22ad_main_search_home%22%20da-data-r%3D%221446%22%20da-data-b%3D%221805%22%20da-type%3D%22n%22%3E%0D%0A%20%20%20%20%20%20%20%20%3Cdiv%0D%0A%20%20%20%20%20%20%20%20%20%20%20%20id%3D%22canvasWrap%22%0D%0A%20%20%20%20%20%20%20%20%20%20%20%20style%3D%22height%3A%20115px%3B%20text-align%3A%20center%3B%20position%3A%20absolute%3B%20bottom%3A%200%3B%20left%3A%200%3B%20right%3A%200%22%0D%0A%20%20%20%20%20%20%20%20%3E%0D%0A%20%20%20%20%20%20%20%20%20%20%20 ...
# ;
# window.gladsdk.cmd.push(function () {
# var slot = window.nmain.getADSlotWithHostMeta({
# adUnitId: "m_main_special",
# adSlotElementId: "main_search_specialda_1",
# customParam: {
# platform: 'web',
# version: 'next',
# menu: 'SEARCH'
# }
# });
# window.gladsdk.setMediationList(ads.payload);
# });
# })();
# </script>
# </div>
#
# <div id="MM_search_container" class="comp_container type_round_card"
# data-is-birthday="false"
# >
# <div class="grid1_wrap brick-house"
# data-contingency="false"
# data-abt="[]"
# data-abt-adcustomparam=""
# >
# <div class="brick-vowel">
# <div id="MM_HOME_SEARCH_WEATHER"
# class="grid1 id_comp_weather _MM_WEATHER_BANNER MM_INSP_CARD_EXP"
# data-insp-card-exp-key="weather"
# data-version-new = "true"
# data-home-feed-id="weather"
# style="display:none;"
# data-block-id=""
# data-block-code="CAS_6170c605d52dbb4f2157aefe"
# data-block-type="SEARCH-CARD-BLOCK"
# data-block-position="3"
# data-template-code="SEARCH-WEATHER"
#
# >
# <div class="comp_weather comp_card cw_fold">
# <div class="cw_title_wrap">
# <h3 class="cw_title"><a href="https://weather.naver.com/today" class="cw_main" data-clk="weatherch">네이버 날씨</a></h3>
# </div>
# <div class="cw_place_wrap">
# <div class="cw_place_info" >
# <a href="https://weather.naver.com/today/09140104?cpName=KMA" class="cw_place  MM_INSP_CARD_EXP_CID_ONLY" data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt1">
# <!--맑음-->
# <div class="sun1"></div>
# <div class="sun2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">3.5°</em> 서울</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/01110101?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt1">
# <!--맑음-->
# <div class="sun1"></div>
# <div class="sun2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">2.8°</em> 춘천</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/01150101?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt1">
# <!--맑음-->
# <div class="sun1"></div>
# <div class="sun2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">5.6°</em> 강릉</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state empty">데이터 없음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/16113104?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt1">
# <!--맑음-->
# <div class="sun1"></div>
# <div class="sun2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">2.8°</em> 청주</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/07110101?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt1">
# <!--맑음-->
# <div class="sun1"></div>
# <div class="sun2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">2.9°</em> 대전</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/06110101?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt5">
# <!--구름많음-->
# <div class="cloud1"></div>
# <div class="sun1"></div>
# <div class="sun2"></div>
# <div class="cloud2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">7.0°</em> 대구</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/08110580?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt5">
# <!--구름많음-->
# <div class="cloud1"></div>
# <div class="sun1"></div>
# <div class="sun2"></div>
# <div class="cloud2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">10.1°</em> 부산</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/13111101?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt1">
# <!--맑음-->
# <div class="sun1"></div>
# <div class="sun2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">4.6°</em> 전주</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/14110630?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt7">
# <!--흐림-->
# <div class="cloud1"></div>
# <div class="cloud2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">7.4°</em> 제주</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/11720330?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt9">
# <!--비-->
# <div class="rain2"></div>
# <div class="rain4"></div>
# <div class="cloud"></div>
# <div class="rain1"></div>
# <div class="rain3"></div>
# <div class="rain5"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">3.5°</em> 백령</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <div class="cw_place_info" style="display: none;">
# <a href="https://weather.naver.com/today/04940250?cpName=KMA" class="cw_place " data-clk-prefix="home.weather">
# <div class="ico_cw_today">
# <div class="wt6">
# <!--밤구름많음-->
# <div class="cloud1"></div>
# <div class="moon"></div>
# <div class="cloud2"></div>
# </div>
# </div>
# <div class="cw_info">
# <strong class="info_main"><em class="temp">6.6°</em> 울릉/독도</strong>
# <div class="info_sub">
# 미세<em class="state good">좋음</em> &middot;
# 초미세<em class="state good">좋음</em></div>
# </div>
# </a>
# </div>
# <button type="button" class="cw_btn_place _MM_WEATHER_LOC" data-clk="weatherhere"><span class="cw_text">내 위치찾기</span></button>
# </div>
# <div class="cw_notice_wrap">
# <p class="notice_guide">위치 찾기를 눌러 현 위치의 시간대별·주간날씨와<br>미세먼지 예보를 여기에서 바로 보세요</p>
# </div>
# </div>
# <script id="MM_search_weather_json" type="text/plain">
# {
# "type": "default",
# "regions": [{"url":"https://weather.naver.com/today/09140104?cpName=KMA","code":"1","text":"맑음","temperature":3.5,"compareTemperature":-5.2,"feelTemperature":1.2,"pm10":7,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":3,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"W","windSpeed":2.4,"humidity":33,"regionName":"서울","smallAreaName":"을지로1가","desc":"어제보다 5.2° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"서울"},{"url":"https://weather.naver.com/today/01110101?cpName=KMA","code":"1","text":"맑음","temperature":2.8,"compareTemperature":-6.9,"feelTemperature":0.9,"pm10":16,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":1,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"SW","windSpeed":1.9,"humidity":29,"regionName":"춘천","smallAreaName":"봉의동","desc":"어제보다 6.9° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"춘천"},{"url":"https://weather.naver.com/today/01150101?cpName=KMA","code":"1","text":"맑음","temperature":5.6,"compareTemperature":-8.5,"feelTemperature":4.3,"pm10":10,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25Color":"#848791","rainAmount":0.0,"windDirection":"W","windSpeed":1.8,"humidity":26,"regionName":"강릉","smallAreaName":"홍제동","desc":"어제보다 8.5° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"강릉"},{"url":"https://weather.naver.com/today/16113104?cpName=KMA","code":"1","text":"맑음","temperature":2.8,"compareTemperature":-7.8,"feelTemperature":2.8,"pm10":16,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":5,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"NW","windSpeed":1.2,"humidity":29,"regionName":"청주","smallAreaName":"운천동","desc":"어제보다 7.8° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"청주"},{"url":"https://weather.naver.com/today/07110101?cpName=KMA","code":"1","text":"맑음","temperature":2.9,"compareTemperature":-9.2,"feelTemperature":1.5,"pm10":16,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":9,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"W","windSpeed":1.5,"humidity":29,"regionName":"대전","smallAreaName":"원동","desc":"어제보다 9.2° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"대전"},{"url":"https://weather.naver.com/today/06110101?cpName=KMA","code":"5","text":"구름많음","temperature":7.0,"compareTemperature":-8.6,"feelTemperature":7.0,"pm10":11,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":1,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"SE","windSpeed":0.8,"humidity":22,"regionName":"대구","smallAreaName":"동인동1가","desc":"어제보다 8.6° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"대구"},{"url":"https://weather.naver.com/today/08110580?cpName=KMA","code":"5","text":"구름많음","temperature":10.1,"compareTemperature":-5.0,"feelTemperature":10.1,"pm10":13,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":7,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"NW","windSpeed":2.4,"humidity":21,"regionName":"부산","smallAreaName":"남포동","desc":"어제보다 5.0° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"부산"},{"url":"https://weather.naver.com/today/13111101?cpName=KMA","code":"1","text":"맑음","temperature":4.6,"compareTemperature":-6.6,"feelTemperature":1.7,"pm10":15,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":7,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"N","windSpeed":3.4,"humidity":30,"regionName":"전주","smallAreaName":"중앙동1가","desc":"어제보다 6.6° 낮아요","dustUrl":"https://weather.naver.com/air/","warnListEmpty":true,"wRegionName":"전주"},{"url":"https://weather.naver.com/today/14110630?cpName=KMA","code":"7","text":"흐림","temperature":7.4,"compareTemperature":-5.7,"feelTemperature":5.2,"pm10":24,"pm10Legend":"좋음","pm10Color":"#00A8FF","pm25":7,"pm25Legend":"좋음","pm25Color":"#00A8FF","rainAmount":0.0,"windDirection":"NE","windSpeed ...
# "warnList": []
# }
# </script>
# </div>
# <script id="MM_search_disaster" type="text/plain">
#
# {
# "banner": [],
# "region" : ""
# }
#
# </script><!-- EMPTY -->
# <!-- EMPTY --><div id="MM_SEARCH_SHOP_LIVE"
# class="grid1 id_comp_common_feed MM_INSP_CARD_EXP"
# style="display: none;"
# data-home-feed-id="shopping-live"
# data-insp-card-exp-key="shopping-live"
# data-block-id=""
# data-block-code="CAS_63524e4d448b5b56bba107e6"
# data-block-type="BLOCK-SEARCH-SHOPPING-LIVE"
# data-block-position="6"
# data-template-code="SEARCH-SHOPPING-LIVE"
#
# >
# <div class="comp_common_feed comp_common comp_card">
# <div class="cc_title_wrap">
# <h3 class="cc_title">
# <span class="cc_main">오늘의 인기 아이템</span>
# </h3>
# </div>
# <div class="cc_clip_wrap">
# <ul class="cc_clip_list">
# <li class="cc_clip_item">
# <a href="https://shoppinglive.naver.com/livebridge/1504652?fm=main&sn=searchbottom&tr=sblim"
# class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY"
# target="_blank"
# data-clk="shopupplay">
# <div class="cc_clip_mw">
# <span class="cc_keyword ">오후 07:00</span>
# <img data-src="https://s.pstatic.net/selected.phinf/MjAyNDExMjZfMjA2/MDAxNzMyNjEwNjAwNDMy.ZeT2qO80KmVCP21iflajAbGCBmE3-xNqMtxdCq4uWuwg.ZF7E7Yzc1w-urm7xXlpCDbzbo1QMEJxm74rLNG35qQog.JPEG/image.jpg?type&#x3D;f288_432_q90" width="100%" height="100%" alt="카누 브랜드데이 기념 특별혜택 LIVE!">
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">카누 브랜드데이 기념 특별혜택 LIVE!</div>
# </div>
# </a>
# <div class="cc_link_channel type_small type_profile">
# <div class="cc_channel_mw">
# <img data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22http%3A%2F%2Fshop1.phinf.naver.net%2F20221213_283%2F1670890537984PYP6e_PNG%2F72026365807581038_1749141616.png%22&amp;service&#x3D;selective&amp;type&#x3D;f54_54_q90" width="20" height="20" alt="카누 공식 브랜드스토어">
# </div>
# <div class="cc_channel_tw">
# <span class="cc_channel_t">카누 공식 브랜드스토어</span>
# </div>
# </div>
# </li>
# <li class="cc_clip_item">
# <a href="https://shoppinglive.naver.com/livebridge/1498580?fm=main&sn=searchbottom&tr=sblim"
# class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY"
# target="_blank"
# data-clk="shopupplay">
# <div class="cc_clip_mw">
# <span class="cc_keyword ">오후 07:00</span>
# <img data-src="https://s.pstatic.net/selected.phinf/MjAyNDExMjdfMjUz/MDAxNzMyNjg0MjE1MTAy.LnLdho7tbJlNLb4wx4dOuDQZdYLqY4mR18LYSlyDavsg.UVMC107ENVyTgICKykTGSge_sLFhbk0Lk3p8Vsjh-UEg.JPEG/image.jpg?type&#x3D;f288_432_q90" width="100%" height="100%" alt="이랜드위크 오픈! 최대 80% 역대급 혜택🔥">
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">이랜드위크 오픈! 최대 80% 역대급 혜택🔥</div>
# </div>
# </a>
# <div class="cc_link_channel type_small type_profile">
# <div class="cc_channel_mw">
# <img data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22http%3A%2F%2Fshop1.phinf.naver.net%2F20200205_204%2F1580894520464UcPUQ_PNG%2F104201599983533897_1127008521.png%22&amp;service&#x3D;selective&amp;type&#x3D;f54_54_q90" width="20" height="20" alt="WHOAU">
# </div>
# <div class="cc_channel_tw">
# <span class="cc_channel_t">WHOAU</span>
# </div>
# </div>
# </li>
# <li class="cc_clip_item">
# <a href="https://shoppinglive.naver.com/livebridge/1500298?fm=main&sn=searchbottom&tr=sblim"
# class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY"
# target="_blank"
# data-clk="shopupplay">
# <div class="cc_clip_mw">
# <span class="cc_keyword ">오후 07:00</span>
# <img data-src="https://s.pstatic.net/selected.phinf/MjAyNDExMjdfMjM1/MDAxNzMyNjk2MDc1Mzg1.dj6KQTUyq0pljdjMk6hmUkuTvl494QMeuNC_RgZliakg.2ub164PIvjZ-VP4oKgK9hw1efEqxhdbbvfyP7XaRZswg.JPEG/image.jpg?type&#x3D;f288_432_q90" width="100%" height="100%" alt="마이밀&amp;마이키즈 최대 77% 나홀로 할인!">
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">마이밀&amp;마이키즈 최대 77% 나홀로 할인!</div>
# </div>
# </a>
# <div class="cc_link_channel type_small type_profile">
# <div class="cc_channel_mw">
# <img data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22http%3A%2F%2Fshop1.phinf.naver.net%2F20221031_251%2F1667182619721JLxD3_PNG%2F68318518418890246_2117377688.png%22&amp;service&#x3D;selective&amp;type&#x3D;f54_54_q90" width="20" height="20" alt="대상웰라이프 본사쇼핑몰">
# </div>
# <div class="cc_channel_tw">
# <span class="cc_channel_t">대상웰라이프 본사쇼핑몰</span>
# </div>
# </div>
# </li>
# <li class="cc_clip_item">
# <a href="https://shoppinglive.naver.com/livebridge/1509101?fm=main&sn=searchbottom&tr=sblim"
# class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY"
# target="_blank"
# data-clk="shopupplay">
# <div class="cc_clip_mw">
# <span class="cc_keyword ">오후 08:00</span>
# <img data-src="https://s.pstatic.net/selected.phinf/MjAyNDExMjdfNzQg/MDAxNzMyNjk1Mjk5MDQ5.yHJon7B00ioO2cUQg4rQKeBeA-VpfrfA2zqsbfNmsZ8g.fg8AdNUSADpr9a_lxXhZejrni5fFSeISF4k7wPA3KxUg.JPEG/image.jpg?type&#x3D;f288_432_q90" width="100%" height="100%" alt="[단하루 사은품]금성침대 베드리움 Winter Sale">
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">[단하루 사은품]금성침대 베드리움 Winter Sale</div>
# </div>
# </a>
# <div class="cc_link_channel type_small type_profile">
# <div class="cc_channel_mw">
# <img data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22http%3A%2F%2Fshop1.phinf.naver.net%2F20200327_131%2F1585293837390Ub9jC_JPEG%2F22653671790491962_483640288.jpg%22&amp;service&#x3D;selective&amp;type&#x3D;f54_54_q90" width="20" height="20" alt="금성침대">
# </div>
# <div class="cc_channel_tw">
# <span class="cc_channel_t">금성침대</span>
# </div>
# </div>
# </li>
# </ul>
# <div class="cc_info _MM_COMMON_ROLLING" data-ui-rolling-interval="30000">
# <a href="https://shoppinglive.naver.com/calendar" data-clk="shoptimetable" class="cc_btn_all">
# <span class="cc_point">편성표</span>
# </a>
# </div>
# </div>
# </div>
# </div>
#
# <div class="grid1 id_comp_commemoration_banner ISSUE-BANNER-AD" style="display:none;" data-issue-banner="ad" data-ad-line-id="2966146" data-imp-tracking="https://siape.veta.naver.com/fxview?eu&#x3D;EU10042673&amp;calp&#x3D;-&amp;oj&#x3D;e%2BHWAYrfz1U7WCFdimRBaWQsB2jEm1%2FNANdcgj4fwLtij%2FE5wjUazCGNcbrnFmKn&amp;ac&#x3D;9053541&amp;src&#x3D;7368061&amp;evtcd&#x3D;V900&amp;x_ti&#x3D;1447&amp;tb&#x3D;&amp;oid&#x3D;&amp;sid1&#x3D;&amp;sid2&#x3D;&amp;rk&#x3D;a6ni0Fuqc6hhqG5llJBkGg&amp;eltts&#x3D;mGHLyxR48YMP%2FVsjjrs2nA%3D%3D&amp;brs&#x3D;Y&amp;&amp;eid&#x3D;V900" data-issue-banner-id="I-2966146" data-block-id=""
# data-block-code="CAS_6170c6410241b248b5fc5bc7"
# data-block-type="BLOCK-SEARCH-ISSUE-BANNER"
# data-block-position="7"
# data-template-code="SEARCH-ISSUE-BANNER"
#
# >
# <div class="comp_commemoration_banner comp_card">
# <div class="ccb_banner ccb_image">
# <a href="https://m.search.naver.com/search.naver?sm&#x3D;mtp_dda&amp;where&#x3D;m&amp;query&#x3D;%ED%8B%B0%ED%8C%8C%EB%8B%88%EC%95%A4%EC%BD%94&amp;omcid&#x3D;dis-kr_naver_headlineda_tiffany_wj_kor_holi_fjw_jwco_202411_ff_cross_krw_headline_text_all_none_none_static_1203_mf&amp;utm_medium&#x3D;display-kr&amp;utm_source&#x3D;naver_headlineda&amp;utm_campaign&#x3D;tiffany_wj_kor_holi_fjw_jwco_202411_ff_cross_krw&amp;utm_content&#x3D;headline_text_all_none_none_static_1203&amp;utm_term&#x3D;mf" target="_blank" class="ccb_a" data-click-tracking="https://ssl.pstatic.net/tveta/libs/1by1.gif" >
# <picture>
# <source srcset="https://ssl.pstatic.net/melona/libs/1517/1517466/24fc120741ce9abb71ed_20241127103237964.png" media="false"
# >
# <img src="https://ssl.pstatic.net/melona/libs/1517/1517466/59bdb24ebbfa9497f9e7_20241127103228308.png" width="320" alt="" class="ccb_img">
# </picture>
# </a>
# </div>
# </div>
# </div>
#
# <div class="grid1 id_comp_anniversary_banner MM_INSP_CARD_EXP"
# style="display:none;"
# data-insp-card-exp-key="anniversary"
# data-block-id=""
# data-block-code="CAS_6170c633aa9de732a3161709"
# data-block-type="SEARCH-CARD-BLOCK"
# data-block-position="9"
# data-template-code="SEARCH-ANNIVERSARY"
#
# >
# <div class="comp_anniversary_banner comp_card">
# <div class="cab_banner">
# <a href="http://naver.me/FN7MeFbN" class="cab_a" data-clk="spbanner" target="_blank">
# <div class="cab_mw">
# <picture>
# ...
# <div class="comp_home_feed comp_card MM_search_card_placeholder">
# <div class="chf_feed_card type_small type_load">
# <div class="chf_feed_wrap">
# <div class="chf_feed_profile"></div>
# <div class="chf_feed_info"></div>
# <div class="chf_feed_info"></div>
# </div>
# <div class="chf_thumb_wrap"></div>
# </div>
# </div>
# <div class="comp_home_feed comp_card MM_search_card_placeholder">
# <div class="chf_feed_card type_load">
# <div class="chf_feed_wrap">
# <div class="chf_feed_profile"></div>
# <div class="chf_feed_info"></div>
# <div class="chf_feed_thumb"></div>
# </div>
# </div>
# </div><div class="grid1 id_comp_cafe_top MM_INSP_CARD_EXP"
# data-home-feed-id="cafe"
# data-insp-card-exp-key="homefeed-cafe"
# style="display: none;"
# data-block-id=""
# data-block-code="CAS_6679072ea065bc3108882bab"
# data-block-type="BLOCK-SEARCH-CAFE"
# data-block-position="19"
# data-template-code="SEARCH-CAFE-WEEKLY-RANKING"
#
# >
# <div class="comp_cafe_top comp_common comp_card">
# <div class="cct_title_wrap">
# <h3 class="cct_title">카페 <span class="cct_point">주간 TOP</span></h3>
# </div>
# <ul class="cc_clip_list type_square">
# <li class="cc_clip_item">
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/10298136/articles/32969985?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjMyOTY5OTg1LCJpc3N1ZWRBdCI6MTczMzIxMzEyOTgxOSwiY2FmZUlkIjoxMDI5ODEzNn0.ldvOdXzGuX3HMRrpfDzdT3dvHIgteIgVtBKNsIdcaWE&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY" data-clk="weekcafecon">
# <div class="cc_clip_mw">
# <img src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNDExMjhfMTE4%2FMDAxNzMyNzYyNjA1MTEz.P26tor__KUYBvZW10usFUzUhKmTGMnr3bQeyP-HhkMUg.aIAIyzGYflegEtYwTHsbm-XfBBOdCoTKnBwVh3u7vBAg.JPEG%2FCYMERA%25EF%25BC%25BF20241128%25EF%25BC%25BF112716.jpg%22&amp;type&#x3D;f330_330&amp;service&#x3D;navermain" width="100%" height="100%" alt="집 반찬" data-no-image>
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">집 반찬</div>
# </div>
# </a>
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/10298136/articles/32969985?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjMyOTY5OTg1LCJpc3N1ZWRBdCI6MTczMzIxMzEyOTgxOSwiY2FmZUlkIjoxMDI5ODEzNn0.ldvOdXzGuX3HMRrpfDzdT3dvHIgteIgVtBKNsIdcaWE&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_channel type_cafe type_small" data-clk="weekcafecon">
# <div class="cc_channel_tw">
# <span class="cc_channel_t">레몬테라스 [인테리어,리폼,DIY,요리,결혼,육아,커뮤니티]</span>
# <span class="cc_channel_box">
# <span class="cc_channel_like"><span class="blind">좋아요</span><span class="num">360</span></span><span class="cc_channel_comment"><span class="blind">댓글</span><span class="num">101</span></span>
# </span>
# </div>
# </a>
# </li>
# <li class="cc_clip_item">
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/10110775/articles/3801485?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjM4MDE0ODUsImlzc3VlZEF0IjoxNzMzMjEzMTI5ODIwLCJjYWZlSWQiOjEwMTEwNzc1fQ.xLRXwoeGtMvRcfNrGOuNjbFyAi5pL_UDBAtcBhsOB78&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY" data-clk="weekcafecon">
# <div class="cc_clip_mw">
# <img src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNDExMjVfMjI4%2FMDAxNzMyNDk2MTk0ODg4.UBlcrMWio4njODvzry6eXVwZpKPybQOTkejLqceqfNQg.OL0wHfQKZPPjqRFjHJZ6kFWQD4uosPSEzrBzXzJKR-Qg.JPEG%2F20241125%25EF%25BC%25BF095404.jpg%22&amp;type&#x3D;f330_330&amp;service&#x3D;navermain" width="100%" height="100%" alt="오늘 후지산  미쳤네요" data-no-image>
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">오늘 후지산  미쳤네요</div>
# </div>
# </a>
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/10110775/articles/3801485?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjM4MDE0ODUsImlzc3VlZEF0IjoxNzMzMjEzMTI5ODIwLCJjYWZlSWQiOjEwMTEwNzc1fQ.xLRXwoeGtMvRcfNrGOuNjbFyAi5pL_UDBAtcBhsOB78&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_channel type_cafe type_small" data-clk="weekcafecon">
# <div class="cc_channel_tw">
# <span class="cc_channel_t">네일동 : 일본여행카페</span>
# <span class="cc_channel_box">
# <span class="cc_channel_like"><span class="blind">좋아요</span><span class="num">105</span></span><span class="cc_channel_comment"><span class="blind">댓글</span><span class="num">38</span></span>
# </span>
# </div>
# </a>
# </li>
# <li class="cc_clip_item">
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/23700418/articles/1243615?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjEyNDM2MTUsImlzc3VlZEF0IjoxNzMzMjEzMTI5ODIwLCJjYWZlSWQiOjIzNzAwNDE4fQ.IiFVoP7zdFmyI7uj2QQysDww5DQLPeVsmUHwNxFdE6w&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY" data-clk="weekcafecon">
# <div class="cc_clip_mw">
# <img src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNDExMjZfMTg0%2FMDAxNzMyNTk4NTY1Njgx.01Xy9hKhYFaEXBMGpZoXy-9bSjg-5Cr9jUZ8jI0cSbEg.G2v4BeKZONjD0FgK3jr1_dqf1SxcTSQIo5a9rJGzPzEg.PNG%2FIMG_5710.png%22&amp;type&#x3D;f330_330&amp;service&#x3D;navermain" width="100%" height="100%" alt="34평 타워형 신축 인테리어 랜선 집들이. (대면형주방)" data-no-image>
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">34평 타워형 신축 인테리어 랜선 집들이. (대면형주방)</div>
# </div>
# </a>
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/23700418/articles/1243615?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjEyNDM2MTUsImlzc3VlZEF0IjoxNzMzMjEzMTI5ODIwLCJjYWZlSWQiOjIzNzAwNDE4fQ.IiFVoP7zdFmyI7uj2QQysDww5DQLPeVsmUHwNxFdE6w&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_channel type_cafe type_small" data-clk="weekcafecon">
# <div class="cc_channel_tw">
# <span class="cc_channel_t">셀프 인테리어 My Home (혼자하는 집수리)</span>
# <span class="cc_channel_box">
# <span class="cc_channel_like"><span class="blind">좋아요</span><span class="num">123</span></span><span class="cc_channel_comment"><span class="blind">댓글</span><span class="num">112</span></span>
# </span>
# </div>
# </a>
# </li>
# <li class="cc_clip_item">
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/23700418/articles/1243204?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjEyNDMyMDQsImlzc3VlZEF0IjoxNzMzMjEzMTI5ODE5LCJjYWZlSWQiOjIzNzAwNDE4fQ.dbznAODIiFh11g_TuNCcmHqmvmqjHBeW9zza9WrEioY&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_clip MM_INSP_CARD_EXP_CID_ONLY" data-clk="weekcafecon">
# <div class="cc_clip_mw">
# <img src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNDExMjZfODUg%2FMDAxNzMyNTQ3NjU3NTY5.zt_3L53CDu_dPkOfJFC2OZJA1RMTE9BNqXrtZ0PV5eMg.6Nz4K3ObItp1Dro4ZG6flPeqmS65_WhFzjwMsuji_p8g.JPEG%2FIMG_6666.JPG%22&amp;type&#x3D;f330_330&amp;service&#x3D;navermain" width="100%" height="100%" alt="주상복합 48평 인테리어 턴키후기" data-no-image>
# </div>
# <div class="cc_clip_tw">
# <div class="cc_clip_t">주상복합 48평 인테리어 턴키후기</div>
# </div>
# </a>
# <a href="https://m.cafe.naver.com/ca-fe/web/cafes/23700418/articles/1243204?art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtcG9wdWxhcg.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjEyNDMyMDQsImlzc3VlZEF0IjoxNzMzMjEzMTI5ODE5LCJjYWZlSWQiOjIzNzAwNDE4fQ.dbznAODIiFh11g_TuNCcmHqmvmqjHBeW9zza9WrEioY&tc=navermain_homefeed_popular_weekly" target="_blank" class="cc_link_channel type_cafe type_small" data-clk="weekcafecon">
# <div class="cc_channel_tw">
# <span class="cc_channel_t">셀프 인테리어 My Home (혼자하는 집수리)</span>
# <span class="cc_channel_box">
# <span class="cc_channel_like"><span class="blind">좋아요</span><span class="num">114</span></span><span class="cc_channel_comment"><span class="blind">댓글</span><span class="num">144</span></span>
# </span>
# </div>
# </a>
# </li>
# </ul>
# <div class="cct_info">
# <a href="https://m.cafe.naver.com/ca-fe/home/cafe-hots?type=weekly&tc=navermain_homefeed_popular_weekly" target="_blank" class="cct_link_more" data-clk="weekcafemore">주간 TOP 모두보기</a>
# </div>
# </div>
# </div><div class="grid1 id_comp_sports_event"
# data-home-feed-id="olympic-2024"
# data-insp-card-exp-key="olympic-2024"
# style="display: none;"
# data-block-id=""
# data-block-code="CAS_6698cfcbf32db73ffb1bd218"
# data-block-type="BLOCK-SEARCH-OLYMPIC"
# data-block-position="20"
# data-template-code="SEARCH-OLYMPIC"
#
# >
# <div class="comp_sports_event comp_card">
# <div class="cse_top_banner">
# <a href="https://m.sports.naver.com/paris2024" target="_blank" class="cse_link_title" data-clk="olympictitle">
# <span class="cse_title_logo"><span class="blind">PARIS 2024</span></span>
# </a>
# <a href="https://m.sports.naver.com/paris2024/medals?pageType=COUNTRY&sortType=goldMedal" target="_blank" class="cse_link_info" data-clk="olympicmore">
# <div class="cse_info_wrap">
# <span class="cse_medal type_gold"><span class="blind">금메달 개수</span><span class="num">13</span></span>
# <span class="cse_medal type_silver"><span class="blind">은메달 개수</span><span class="num">9</span></span>
# <span class="cse_medal"><span class="blind">동메달 개수</span><span class="num">10</span></span>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="brick-vowel"></div>
# <div class="brick-vowel"></div>
# </div>
# <div class="comp_pad_wrap id_comp_promotion">
# <div id="MM_search_todaynaver" class="grid1 id_comp_today_feed MM_INSP_CARD_EXP" style="display: none;"
# data-insp-card-exp-key="search-promotion" data-home-feed-id="promotion"
# data-block-id=""
# data-block-code="CAS_6170c6710241b248b5fc5bcd"
# data-block-type="BLOCK-SEARCH-PROMOTION"
# data-block-position="14"
# data-template-code="SEARCH-PROMOTION"
#
# >
# <div class="comp_today_feed comp_card">
# <div class="ctf_feed_wrap">
# <div class="ctf_title_wrap">
# <a class="ctf_link_title type_small" href="https://campaign.naver.com/promotion/" target="_blank" data-clk="prmore">
# <h3 class="ctf_title">
# <span class="ctf_thumb"><img src="https://s.pstatic.net/static/www/mobile/edit/20230905_1095/upload_1693912217924r86zV.jpg" width="20" height="20" alt=""></span><span class="ctf_main">오늘 네이버</span>
# </h3>
# </a>
# </div>
# <div class="ctf_feed_box">
# <div class="comp_snap_list native_scroll">
# <div class="comp_snap_item">
# <!-- EMPTY --></div>
# <div class="comp_snap_item">
# <!-- EMPTY --></div>
# <div class="comp_snap_item">
# <!-- EMPTY --></div>
# <div class="comp_snap_item">
# <!-- EMPTY --></div>
# </div>
# <div class="ctf_pagination">
# <button type="button" class="ctf_dot" aria-current="false"><span class="blind">1페이지</span></button>
# <button type="button" class="ctf_dot" aria-current="false"><span class="blind">2페이지</span></button>
# <button type="button" class="ctf_dot" aria-current="false"><span class="blind">3페이지</span></button>
# <button type="button" class="ctf_dot" aria-current="false"><span class="blind">4페이지</span></button>
# </div>
# </div>
# <div class="ctf_feed_activity">
# <div class="ctf_activity_box">
# <button id="MM_search_todaynaver_splugin" type="button" class="ctf_btn_share naver-splugin" data-clk="feedtkshare"><span class="blind">공유하기</span></button>
# </div>
# <div class="ctf_activity_box">
# <button id="MM_search_todaynaver_keep" type="button" aria-pressed="false" class="ctf_btn_keep"><span class="blind">keep</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script id="MM_search_tab_bubble_json" type="text/plain">
# [
# {"@type":"MATERIAL-SEARCH-TAB-BUBBLE","gdid":null,"title":"핫플 리뷰의 신을 찾습니다","url":null,"id":"TAB_BUBBLE_674962d7abddea32d19eedee","tab":"CLIP","startAt":"2024-12-03 16:00","endAt":"2024-12-03 23:59","_id":null}
# ]
# </script>
# </div>
# </div> <div class="main_footer"> <div class="mf_tool_wrap MM_FOOTER_TOOLS"> <div class="mf_tool_font"> <button type="button" class="mf_btn_font small MM_FONT_SIZE_DOWN" disabled="disabled" data-fclk="fotshowsmall"> 가 <span class="ico_minus"><span class="blind">글자작게보기</span></span> </button> <button type="button" class="mf_btn_font MM_FONT_SIZE_UP" disabled="disabled" data-fclk="fotshowlarge"> 가 <span class="ico_plus"><span class="blind">글자크게보기</span></span> </button> </div> <div class="mf_tool"> <button type="button" class="mf_btn_share naver-splugin" data-fclk="fotcontshr" data-clickcode="pagesend" data-style="one-button" data-title="네이버 모바일 메인" data-pholar-display="off" data-disco-display="off" data-cafe-method="get" data-blog-method="get"><span class="blind">공유하기</span></button> <button type="button" class="mf_btn_top MM_TO_TOP" data-fclk="fotshowupgo"><span class="blind">최상단으로 이동</span></button> </div> </div> <p class="mf_font_info" style="opacity:0"></p> <footer role="contentinfo"> <div class="mf_info_wrap"> <div class="mf_info">  <a href="#" class="mf_info_link MM_LOGINOUT" data-fclk="fot.login">로그인</a>  <a href="/services.html" class="mf_info_link" data-fclk="fot.sitemap">전체서비스</a>  <a href="http://www.naver.com/?mobile" class="mf_info_link" data-fclk="fot.gopc">PC버전</a>  </div> <div class="mf_info"> <a href="http://nid.naver.com/mobile/user/help/termAgree.nhn?m=viewTermAgree1" class="mf_info_link" data-fclk="fot.agreement">이용약관</a> <a href="http://nid.naver.com/mobile/user/help/termAgree.nhn?m=viewTermAgree3" class="mf_info_link" data-fclk="fot.privacy"><strong>개인정보처리방침</strong></a> <a href="https://help.naver.com/index.help" class="mf_info_link" data-fclk="fotconthelp">고객센터</a> </div> <div class="mf_info"> <a href="https://www.navercorp.com" class="mf_logo_naver" data-fclk="fot.navercorp">네이버</a> </div> </div> </footer> </div> </div> </div> </div> </div> </div> <div id="MM_HOME_NUDGE_BANNER" class="nudge_banner"></div> </div> <div id="__MM_NEWS_CHANNEL_SUBSCRIBE_LAYER" class="layer_toast_journal_subscribe" style="display:none"> <button type="button" class="lt_btn_set _MM_NEWS_CHANNEL_SUBSCRIBE_LAYER_DO" data-from="main_category" data-clk="editnlthree">언론사 구독</button> </div> <div id="__MM_EAT_HOT_PLACE_TOAST_LAYER" class="layer_toast lt_food_place" style="display:none"> </div> <div id="_MM_PLUS_DEAL_COUPON" class="layer_plusdeal_float" style="display:none"> </div> <div id="__MM_MF_RECOMMEND_FILTER_TOAST_LAYER" class="layer_toast" style="display:none"> <p class="lt_t">키워드 구독은 최대 14개까지 설정할 수 있습니다.</p> </div> <div id="__MM_OS_SUBSCRIBE_POPUP" class="layer_popup" style="display:none;z-index:3000"> <div class="notice_popup"> <div class="info_area"> <strong class="title">네이버 앱 푸시알림이 꺼져있어요.</strong> <div class="desc_box"> <p class="desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p> <p class="desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p> </div> </div> <div class="button_area"> <button type="button" class="btn_func _MM_OS_SUBSCRIBE_POPUP_CLOSE" data-clk="osnotoff">닫기</button> <button type="button" class="btn_func highlight _MM_OS_SUBSCRIBE_POPUP_ACTIVE" data-clk="osnoton">네이버 앱 알림 켜기</button> </div> </div> </div> <div id="MM_SCRIPTS" style="display:none"></div> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/mo/main/min/mo.veta.core.min.js?20180328"></script> <div id="MM_TOAST_LAYER" class="layer_toast lt_foreign_nation"></div> <div id="MM_refresh_home_feed" class="layer_toast lt_feed_alert" style="bottom:auto;display:none"> <button type="button" class="lfa_btn_refresh MM_renew"> <span class="ico_lfa_refresh"></span> <span class="lfa_text">새로운 추천 받기</span> </button> </div> <div id="MM_ALERT_LAYER" class="layer_alert" style="display:none"></div> <div id="MM_ALERT_T18" class="layer_myfeed_menu lmm_show" style="display:none"></div> <div id="MM_ALERT_T19" class="layer_declaration" style="display:none"></div> <div id="MM_SHORTS_PORTAL"></div> <div id="MM_SHORTS_shopping_live_dialog" style="position:absolute;z-index:999999;pointer-events:none;top ...

# %%
import requests

# %%
requests.get('https://m.naver.com').text
# Out:
# '<!doctype html>                                                        <html lang="ko" class="web fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta name="referrer" contents="always"> <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 모바일 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버 모바일 메인"> <meta property="og:url" content="http://m.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/20240816_0/upload_17238016633431Iokd.jpg"> <meta property="og:description" content="네이버 모바일 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content="네이버 모바일 메인"> <meta name="twitter:url" content="http://m.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/20240816_0/upload_17238016633431Iokd.jpg"> <meta name="twitter:description" content="네이버 모바일 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <title>NAVER</title>  <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602713093y05hN.png"/> <link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602618538tqxrL.png"/> <link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602698312FhzB6.png"/> <link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://s.pstatic.net/static/www/mobile/edit/20240814_0/upload_1723602600973mkojJ.png"/>  <link rel="stylesheet" type="text/css" href="https://mm.pstatic.net/css/ncache/build/w.b6648cf4.css"> <link rel="stylesheet" type="text/css" href="https://mm.pstatic.net/css/ncache/build/w_dark.4ef58721.css" media="false">  <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico"> <link rel="canonical" href="https://www.naver.com/"> <script>window.nsc="mtop.v6",window.svt="20241203172520",window.g_ssc=window.nsc,window.nmain={},window.logsrv="l.m.naver.com"</script> <script> window.nmain.buildTime = "202412031054";\n    window.nmain.gv = {\n      jsOrigin: "m",  isLogin: false,   generation : -1,   isContentsOnly: false,\n      isApp: false,\n      isPad: false,\n      isWhaleSidebar: false,\n      daInfo: {"SHOPPING_MEN_W":{"adType":"sequence","units":[{"unitId":"m_main_shoppingwest_1st","divId":"nmap_shopping_men_w_1","position":"abs","positionIndex":4,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_shopping_west_0size","divId":"nmap_shopping_men_w_3","position":"abs","positionIndex":9,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":"men"}},{"unitId":"m_main_shoppingwest_2nd","divId":"nmap_shopping_men_w_2","position":"abs","positionIndex":11,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}}]},"DISCOVER":{"adType":"sequence","units":[{"unitId":"m_main_watch_top","divId":"nmap_discover_top","position":"rel","positionIndex":0,"adPositionAdjustFlag":true,"adCallType":"preload","extraOption":{"calp":null}},{"unitId":"m_main_pick_feed","divId":"nmap_discover_6","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}}]},"SHOP-TODO-KIDS":{"adType":"sequence","units":[{"unitId":"m_main_todokids_1st","divId":"nmap_shop-todo-kids_1","position":"abs","positionIndex":4,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}},{"unitId":"m_main_todokids_2nd","divId":"nmap_shop-todo-kids_2","position":"abs","positionIndex":9,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"calp":null}}]},"ENT":{"adType":"sequence","units":[{"unitId":"m_main_ent_1st","divId":"nmap_ent_1","position":"rel","positionIndex":0,"adPositionAdjustFlag":null,"adCallType":null,"extraOption":{"cal ...

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
</body>
</html>
"""

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(html_doc,"html.parser")

# %%
soup.prettify()
# Out:
# '<html>\n <head>\n  <title>\n   The Dormouse\'s story\n  </title>\n </head>\n <p class="title">\n  <b>\n   The Dormouse\'s story\n  </b>\n </p>\n <p class="story">\n  Once upon a time there were three little sisters; and their names were\n  <a class="sister" href="http://example.com/elsie" id="link1">\n   Elsie\n  </a>\n  ,\n  <a class="sister" href="http://example.com/lacie" id="link2">\n   Lacie\n  </a>\n  and\n  <a class="sister" href="http://example.com/tillie" id="link3">\n   Tillie\n  </a>\n  ;\nand they lived at the bottom of a well.\n </p>\n <p class="story">\n  ...\n </p>\n</html>\n'

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id='link2')
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
soup.find_all('p',{'class':'story'})
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.find('p'),soup.find_all('p')
# Out:
# (<p class="title"><b>The Dormouse's story</b></p>,
#  [<p class="title"><b>The Dormouse's story</b></p>,
#   <p class="story">Once upon a time there were three little sisters; and their names were
#   <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#   <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#   <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#   and they lived at the bottom of a well.</p>,
#   <p class="story">...</p>])

# %%
soup.a.get_text()
# Out:
# 'Elsie'

# %%
soup.p.get_text()
# Out:
# "The Dormouse's story"

# %%
#soup.find_all('p',{'class':'story'})[0].get_text()
soup.p.string.replace_with('edit')
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <p class="title"><b>edit</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </html>

# %%
soup.find(text='Elsie')
# Out:
# C:\Users\Supervisor\AppData\Local\Temp\ipykernel_18672\1305314666.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soup.find(text='Elsie')
# 'Elsie'

# %%
soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
list(soup.body.children)
# Out:
# ['\n',
#  <p class="title"><b>The Dormouse's story</b></p>,
#  '\n',
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  '\n',
#  <p class="story">...</p>,
#  '\n']

# %%
soup.body.contents[3].contents[0]
# Out:
# 'Once upon a time there were three little sisters; and their names were\n'

# %%
soup.p.next_sibling.next_sibling
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
